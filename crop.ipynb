# %% [markdown]
# ### 학습한 YOLOv5 이용하여 detect & crop

# %%
import os
import IPython.display

# %%
print(os.getcwd())
# Out:
# /home/user/YOLOv5/yolov5

# %%
# %cd YOLOv5/yolov5
# Out:
# /home/user/YOLOv5/yolov5

# %%
# %pwd
# Out:
# '/home/user/YOLOv5/yolov5'

# %%
# 테스트 이미지 경로
test_data_dir = "../../datasets/차알/test_차알"

# 실험 번호 지정 - 진행한 실험이 저장된 경로 확인해서 기입! - runs/train/exp1 인지 exp2, exp3 인지 확인 후 아래 번호 지정
train_exp_num = 2

# %%
# !python detect.py --weights runs/train/exp{train_exp_num}/weights/best.pt --img 416 --conf 0.1 --source {test_data_dir} --save-crop
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../../datasets/차알/test_차알, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-243-g7c54e5d Python-3.9.18 torch-2.1.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7180036 parameters, 0 gradients, 16.3 GFLOPs
# image 1/350 /home/user/datasets/차알/test_차알/차알_음식_0.jpg: 288x416 (no detections), 66.9ms
# image 2/350 /home/user/datasets/차알/test_차알/차알_음식_1.jpg: 288x416 1 Sandwich, 5.3ms
# image 3/350 /home/user/datasets/차알/test_차알/차알_음식_10.jpg: 416x416 16 Tomatos, 7.0ms
# ...
